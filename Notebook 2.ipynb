# %%
library(ggplot2)
library(scales)

data <- data.frame(
  Provider = c('Provider A', 'Provider B', 'Provider C'),
  ProjectsDone = c(50, 75, 60),  # Replace with your actual data
  RepaidRate = c(0.8, 0.9, 0.85)  # Replace with your actual data
)

data$ProjectsDone <- rescale(data$ProjectsDone)

data_long <- tidyr::gather(data, key = "Metric", value = "Value", -Provider)


p <- ggplot(data_long, aes(x = Provider, y = Value, fill = Metric)) +
  geom_bar(stat = "identity", position = "dodge", width = 0.7) +
  labs(x = "Providers", y = "Projects Done (Standardized)", fill = "") +
  scale_fill_manual(values = c("blue", "green"), name = "Metric",
                    labels = c("Projects Done", "Repaid Rate")) +
  theme_minimal()


p + scale_y_continuous(sec.axis = sec_axis(~., name = "Repaid Rate", labels = scales::percent))
# Out:
# plot without title

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=daed34fc-226e-4d0c-93e0-93bc5ec19f10' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
